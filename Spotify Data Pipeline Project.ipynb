# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="2c65b37607de4ed397a2b6b249b36797", client_secret="33c843048017444a80f894c676b7b1b9")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
data['items']
# Out:
# [{'added_at': '2024-07-08T12:16:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-07-08T12:16:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5quMTd5zeI9yW5UDua8wS4'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Espresso'

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Sabrina Carpenter'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-04-12'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_artist = row['track']['album']['artists'][0]['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'id':album_id, 'name':album_name, 'artist':album_artist, 'release_date':album_release_date,'total_tracks':album_total_tracks, 'url':album_url}

    album_list.append(album_element)

# %%
album_list
# Out:
# [{'id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'artist': 'Sabrina Carpenter',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'artist': 'Billie Eilish',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'id': '5bBaoign62r1i7OV8w7mi9',
#   'name': 'Please Please Please',
#   'artist': 'Sabrina Carpenter',
#   'release_date': '2024-06-06',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'name': 'Not Like Us',
#   'artist': 'Kendrick Lamar',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'id': '5tSQtQGkrCJx3hoQxmLgfM',
#   'name': 'Gata Only',
#   'artist': 'FloyyMenor',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-07-08T12:16:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name': artist['name'], 'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_url': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'external_url': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name': song_name, 'song_duration':song_duration, 'url':song_url, 'popularity':song_popularity,
                    'song_added':song_added, 'album_id':album_id, 'artist_id': artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'song_duration': 175459,
#   'url': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75',
#   'popularity': 99,
#   'song_added': '2024-07-08T12:16:25Z',
#   'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'song_duration': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 98,
#   'song_added': '2024-07-08T12:16:25Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5N3hjp1WNayUPZrA8kJmJP',
#   'song_name': 'Please Please Please',
#   'song_duration': 186365,
#   'url': 'https://open.spotify.com/track/5N3hjp1WNayUPZrA8kJmJP',
#   'popularity': 98,
#   'song_added': '2024-07-08T12:16:25Z',
#   'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                        id                  name             artist  \
# 0  5quMTd5zeI9yW5UDua8wS4              Espresso  Sabrina Carpenter
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT      Billie Eilish
# 2  5bBaoign62r1i7OV8w7mi9  Please Please Please  Sabrina Carpenter
# 3  5JjnoGJyOxfSZUZtk2rRwZ           Not Like Us     Kendrick Lamar
# 4  5tSQtQGkrCJx3hoQxmLgfM             Gata Only         FloyyMenor
#
#   release_date  total_tracks  \
# 0   2024-04-12             1
# 1   2024-05-17            10
# 2   2024-06-06             2
# 3   2024-05-04             1
# 4   2024-02-02             1
#
#                                                  url
# 0  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 4  https://open.spotify.com/album/5tSQtQGkrCJx3ho...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            50 non-null     object
#  1   name          50 non-null     object
#  2   artist        50 non-null     object
#  3   release_date  50 non-null     object
#  4   total_tracks  50 non-null     int64
#  5   url           50 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.5+ KB

# %%
album_df = album_df.drop_duplicates(subset=['id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 1  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 2  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3  2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar
# 4  7CvTknweLr9feJtRGrpDBy         FloyyMenor
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 1  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 2  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 3  https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# 4  https://api.spotify.com/v1/artists/7CvTknweLr9...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id             song_name  song_duration  \
# 0  2qSkIjg1o9h3YT9RAgYN75              Espresso         175459
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER         210373
# 2  5N3hjp1WNayUPZrA8kJmJP  Please Please Please         186365
# 3  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us         274192
# 4  6XjDF6nds4DE2BBbagZol6             Gata Only         222000
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          99
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          98
# 2  https://open.spotify.com/track/5N3hjp1WNayUPZr...          98
# 3  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...          96
# 4  https://open.spotify.com/track/6XjDF6nds4DE2BB...          96
#
#              song_added                album_id               artist_id
# 0  2024-07-08T12:16:25Z  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
# ...

# %%
album_df.head()
# Out:
#                        id                  name             artist  \
# 0  5quMTd5zeI9yW5UDua8wS4              Espresso  Sabrina Carpenter
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT      Billie Eilish
# 2  5bBaoign62r1i7OV8w7mi9  Please Please Please  Sabrina Carpenter
# 3  5JjnoGJyOxfSZUZtk2rRwZ           Not Like Us     Kendrick Lamar
# 4  5tSQtQGkrCJx3hoQxmLgfM             Gata Only         FloyyMenor
#
#   release_date  total_tracks  \
# 0   2024-04-12             1
# 1   2024-05-17            10
# 2   2024-06-06             2
# 3   2024-05-04             1
# 4   2024-02-02             1
#
#                                                  url
# 0  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 4  https://open.spotify.com/album/5tSQtQGkrCJx3ho...

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            48 non-null     object
#  1   name          48 non-null     object
#  2   artist        48 non-null     object
#  3   release_date  48 non-null     datetime64[ns]
#  4   total_tracks  48 non-null     int64
#  5   url           48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 2.6+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        50 non-null     object
#  1   song_name      50 non-null     object
#  2   song_duration  50 non-null     int64
#  3   url            50 non-null     object
#  4   popularity     50 non-null     int64
#  5   song_added     50 non-null     datetime64[ns, UTC]
#  6   album_id       50 non-null     object
#  7   artist_id      50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
